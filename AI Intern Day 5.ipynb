# %% [markdown]
# ## Matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4])
plt.ylabel('some numbers')
plt.xlabel('some other numbers')
plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'k')
plt.show()

# %%
plt.plot([1, 2, 3, 4, 10], [1, 4, 9, 16, 100], 'go')
plt.axis([0, 6, 0, 20]) # xmin, xmax, ymin, ymax
plt.show()

# %%
import numpy as np

# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')

plt.show()

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(1, 3, 1) # Total 1 rows, 3 columns and this is the first plot
plt.bar(names, values)
plt.subplot(1, 3, 2)
plt.scatter(names, values)
plt.subplot(1, 3, 3)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %% [markdown]
# ### Multiple figures and axis

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(2, 1, 2)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
import matplotlib.pyplot as plt

abc = plt.figure(1)                # the first figure
plt.subplot(2,1,1)             # the first subplot in the first figure
plt.plot([1, 2, 3])
plt.subplot(2, 1, 2)             # the second subplot in the first figure
plt.plot([4, 5, 6])


plt.figure(2)                # a second figure
plt.plot([4, 5, 6])          # creates a subplot(111) by default

plt.figure(1)                # figure 1 current; subplot(212) still current
plt.subplot(2, 1, 1)             # make subplot(211) in figure1 current
plt.title('Easy as 1, 2, 3') # subplot 211 title

plt.show()
# abc.savefig('fig_name.png')

# %% [markdown]
# ### Adding text

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability', fontsize=14, color='red')
plt.title('Histogram of IQ')
plt.text(60, .025, '100')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
fig = plt.figure()
ax = plt.subplot(1,1,1)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()

# %%
fig.savefig('abc.png')

# %% [markdown]
# ### Images with matplotlib

# %%
import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
from PIL import Image
import numpy as np


img = Image.open("./logo.png")
img2 = Image.open("./logo2.png")

# %%
plt.imshow(img)
plt.show()

# %%
w=10
h=10
fig=plt.figure(figsize=(8, 8))
columns = 2
rows = 1

location = ['./logo.png', './logo2.png']

for i in range(columns*rows):
    img = Image.open(location[i])
#     fig.add_subplot(rows, columns, i+1)
    plt.figure(figsize=(4,4))
    plt.imshow(img)
plt.show()

# %% [markdown]
# ## Pandas

# %%
# Series is a one-dimensional labeled array capable of holding 
# any data type
import pandas as pd

s = pd.Series(np.random.randint(5, size=10))

# %% [markdown]
# Here, data can be many different things:
#
#     a Python dict
#
#     an numpy array
#
#     a scalar value (like 5)

# %%
s
# Out:
# 0    0
# 1    2
# 2    4
# 3    0
# 4    3
# 5    2
# 6    1
# 7    0
# 8    4
# 9    4
# dtype: int64

# %% [markdown]
# DataFrame is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object. Like Series, DataFrame accepts many different kinds of input:
#
#     Dict of 1D ndarrays, lists, dicts, or Series
#
#     2-D numpy.ndarray
#
#     Structured or record ndarray
#
#     A Series
#
#     Another DataFrame

# %%
df_new = pd.read_csv("./heart.csv")

df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df_new.shape
# Out:
# (303, 14)

# %%
df_new['age'] # Series
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
df_new.age # Not recommended
# Out:
# 0      63
# 1      37
# 2      41
# 3      56
# 4      57
#        ..
# 298    57
# 299    45
# 300    68
# 301    57
# 302    57
# Name: age, Length: 303, dtype: int64

# %%
simple = np.arange(303)

df_new['simple'] = simple

df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
df_new.iloc[:3, :2] # Row and column index
# Out:
#    age  sex
# 0   63    1
# 1   37    1
# 2   41    0

# %%
df_new.loc[:3, :'sex']
# Out:
#    age  sex
# 0   63    1
# 1   37    1
# 2   41    0
# 3   56    1

# %%
df_new['age']>60
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 298    False
# 299    False
# 300     True
# 301    False
# 302    False
# Name: age, Length: 303, dtype: bool

# %%
# Masking as indexing

df_new.loc[df_new['age']>60, ['sex', 'cp']]
# Out:
#      sex  cp
# 0      1   3
# 13     1   3
# 17     0   3
# 19     0   3
# 23     1   2
# ..   ...  ..
# 290    1   0
# 293    1   2
# 295    1   0
# 296    0   0
# 300    1   0
#
# [79 rows x 2 columns]

# %%
df_new.iloc[0, 0] = 90

df_new.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
df_new.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target', 'simple'],
#       dtype='object')

# %%
df_new.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# simple        int64
# dtype: object

# %%
# ?df_new.mean

# %%
df_new.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.455446    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.297003    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     90.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
df_new.sort_values(by='age')

# If you want to modify actual dataframe
# Use 
# df_new = df_new.sort_values(by='age')
# Use iloc to access data after sorting
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 72    29    1   1       130   204    0        0      202      0      0.0
# 125   34    0   1       118   210    0        1      192      0      0.7
# 58    34    1   3       118   182    0        0      174      0      0.0
# 157   35    1   1       122   192    0        1      174      0      0.0
# 65    35    0   0       138   183    0        1      182      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 25    71    0   1       160   302    0        1      162      0      0.4
# 129   74    0   1       120   269    0        0      121      1      0.2
# 144   76    0   2       140   197    0        2      116      0      1.1
# 238   77    1   0       125   304    0        0      162      1      0.0
# 0     90    1   3       145   233    1        0      150      0      2.3
#
#      slope  ca  thal  target  simple
# 72       2   0     2       1      72
# ...

# %%
df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
df_new.dropna(axis=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# ...

# %%
df_new.fillna(value = 5, axis=0)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# ...

# %%
df_new.mean()
# Out:
# age          54.455446
# sex           0.683168
# cp            0.966997
# trestbps    131.623762
# chol        246.264026
# fbs           0.148515
# restecg       0.528053
# thalach     149.646865
# exang         0.326733
# oldpeak       1.039604
# slope         1.399340
# ca            0.729373
# thal          2.313531
# target        0.544554
# simple      151.000000
# dtype: float64

# %%
def label_senior(row):
    if row.age > 60:
        return 'senior'
    else:
        return 'young'

df_new['test_col'] = df_new.apply(label_senior, axis=1)

print(df_new.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple test_col
# 0   0     1       1       0   senior
# 1   0     2       1       1    young
# 2   0     2       1       2    young
# 3   0     2       1       3    young
# 4   0     2       1       4    young

# %%
df_new = df_new.drop('test_col', axis=1)

# %%
df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
# all should have the same cols

pieces = [df_new[:30], df_new[30:]]

print(pieces[0].shape)

pd.concat(pieces)
# Out:
# (30, 15)
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     90    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  simple
# 0        0   0     1       1       0
# ...

# %%
left = pd.DataFrame({'key': ['foo1', 'foo2'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo2', 'foo1'], 'rval': [4, 5]})
left
# Out:
#     key  lval
# 0  foo1     1
# 1  foo2     2

# %%
right
# Out:
#     key  rval
# 0  foo2     4
# 1  foo1     5

# %%
pd.merge(left, right, on='key')
# Out:
#     key  lval  rval
# 0  foo1     1     5
# 1  foo2     2     4

# %%
df_new.groupby('sex').mean()
# Out:
#            age        cp    trestbps        chol      fbs   restecg  \
# sex
# 0    55.677083  1.041667  133.083333  261.302083  0.12500  0.572917
# 1    53.888889  0.932367  130.946860  239.289855  0.15942  0.507246
#
#         thalach     exang   oldpeak     slope        ca      thal    target  \
# sex
# 0    151.125000  0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    148.961353  0.371981  1.115459  1.386473  0.811594  2.400966  0.449275
#
#          simple
# sex
# 0    125.166667
# 1    162.980676

# %%
df_new.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   90    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target  simple
# 0   0     1       1       0
# 1   0     2       1       1
# 2   0     2       1       2
# 3   0     2       1       3
# 4   0     2       1       4

# %%
df_new.to_csv("./hearts2.csv")

# %%
# !ls
# Out:
#  abc.png			  heart.csv
# 'AI Intern Day 5.ipynb'		  hearts2.csv
# 'AI Intern Day 5.pdf'		  logo2.png
# 'Assignment 3 (Beginner).ipynb'   logo.png
# 'Assignment 3 (Beginner).pdf'	  Pandas_Cheat_Sheet.pdf
#  auto-mpg.csv			  text.png
